# %% [markdown]
# <a href="https://colab.research.google.com/github/TiTKi1/Coursework/blob/master/%D0%9C%D0%B0%D0%BC%D0%B5%D0%B4%D0%BE%D0%B2_%D0%A0_%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0_%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B0_4_%D0%92_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Мамедов Руслан був присутній на парі

# %%
#Встaновити numpy
#!pip install numpy

# %%
# Приклади роботи з матрицями
import numpy as np
# Отримання версії бібліотеки NumPy
numpy_version = np.__version__
numpy_version
# Out:
# '2.0.2'

# %%
import numpy as np
matrix = np.random.randint(1, 6, size=(3,3))
matrix
# Out:
# array([[1, 5, 5],
#        [3, 2, 2],
#        [5, 4, 5]])

# %%
det = np.linalg.det(matrix)
det
# Out:
# np.float64(-13.0)

# %%
product = np.prod(matrix)
product
# Out:
# np.int64(30000)

# %%
prod_1 = np.prod(matrix[0])
prod_2 = np.prod(matrix[1])
prod_3 = np.prod(matrix[2])
prod_1*prod_2*prod_3
# Out:
# np.int64(30000)

# %%
np.sum(matrix)
# Out:
# np.int64(32)

# %%
min = np.min(matrix)
print("Мінімальне значення матриці", min)
# Out:
# Мінімальне значення матриці 1

# %%
max = np.max(matrix)
print("Максимальне значення матриці", max)
# Out:
# Максимальне значення матриці 5

# %%
mean = np.mean(matrix)
print ("Середнє значення матриці", mean)
# Out:
# Середнє значення матриці 3.5555555555555554

# %%
sqrt_matrix = np.sqrt(matrix)
print("Матриця квадртаних коренів")
print(sqrt_matrix)
# Out:
# Матриця квадртаних коренів
# [[1.         2.23606798 2.23606798]
#  [1.73205081 1.41421356 1.41421356]
#  [2.23606798 2.         2.23606798]]

# %%
row_sums = np.sum(matrix, axis=1).reshape(-1,1)
print(row_sums)
# Out:
# [[11]
#  [ 7]
#  [14]]

# %%
x = np.matrix([[2, 3], [2, 4]])
x
# Out:
# matrix([[2, 3],
#         [2, 4]])

# %%
x.sum(axis=1)
# Out:
# matrix([[5],
#         [6]])

# %%
x.sum(axis=1,dtype=float)
# Out:
# matrix([[5.],
#         [6.]])

# %%
vector = np.random.randint(-10,10, size = 25)
vector
# Out:
# array([ -7,   9,   9,  -8,  -4,  -4,   8,   1,  -5,   4,  -7,  -8,   6,
#          8, -10,   6,  -9,   8,  -6, -10,  -7,   9,  -9, -10,  -2])

# %%
sorted_vector = np.sort(vector)[::-1]
sorted_vector
# Out:
# array([  9,   9,   9,   8,   8,   8,   6,   6,   4,   1,  -2,  -4,  -4,
#         -5,  -6,  -7,  -7,  -7,  -8,  -8,  -9,  -9, -10, -10, -10])

# %%
from scipy import stats
mode = stats.mode(vector)
median = np.median(vector)
mean = np.mean(vector)
max = np.max(vector)
min = np.min(vector)
print("Мода:",mode)
print("Медіана:",median)
print("Середнє:",mean)
print("Максимальне значення:",max)
print("Мінімальне значення:",min)
# Out:
# Мода: ModeResult(mode=np.int64(-10), count=np.int64(3))
# Медіана: -4.0
# Середнє: -1.52
# Максимальне значення: 9
# Мінімальне значення: -10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
a = np.array([
    [1, -2, 1],
    [2, -1, 1],
    [3, 2, 2],
])
b = np.array([[4], [3], [2]])

# %%
#Матричний метод (1 спосіб)
det_a = np.linalg.det(a)
if det_a == 0:
    print("Визначник дорівнює нулю - рішень немає")
else:
  a_inv = np.linalg.inv(a)
  print(f"Обернена матриця до матриці A: \r\n {a_inv }")
  print(f"Вектор рішення: \r\n {a_inv.dot(b)}")
# Out:
# Обернена матриця до матриці A:
#  [[-0.8  1.2 -0.2]
#  [-0.2 -0.2  0.2]
#  [ 1.4 -1.6  0.6]]
# Вектор рішення:
#  [[-2.22044605e-16]
#  [-1.00000000e+00]
#  [ 2.00000000e+00]]

# %%
# Напиши функцію для вирішення системи матричним методом (2 спосіб)
def solve_inv_matrix(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    a_inv= np.linalg.inv(a)
    if verbose: print(f"Обернена матриця до матриці A: \r\n {a_inv }")
    return a_inv.dot(b)

print(f"Вектор рішення: \r\n {solve_inv_matrix(a, b)}")
# Out:
# Вектор рішення:
#  [[-2.22044605e-16]
#  [-1.00000000e+00]
#  [ 2.00000000e+00]]

# %%
#метод Крамера (1 спосіб)
# Метод Крамера
det_a = np.linalg.det(a)

if det_a == 0:
    print("Визначник дорівнює нулю — система не має єдиного розв’язку.")
else:
    def replace_column(matrix, column_index, new_column):
        new_matrix = np.copy(matrix)
        new_matrix[:, column_index] = new_column
        return new_matrix

    # Обчислюємо Δx, Δy, Δz
    delta_x = np.linalg.det(replace_column(a, 0, b.T))
    delta_y = np.linalg.det(replace_column(a, 1, b.T))
    delta_z = np.linalg.det(replace_column(a, 2, b.T))

    # Обчислюємо x, y, z
    print('x =', delta_x / det_a)
    print('y =', delta_y / det_a)
    print('z =', delta_z / det_a)
# Out:
# x = 0.0
# y = -1.0
# z = 2.0

# %%
# Напиши функцію для вирішення системи методом Крамера
def solve_cramer(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    len_a = len(a)
    x = np.zeros((len_a, 1))
    for i in range(len_a):
        temp = np.copy(a)
        temp[:, [i]] = b
        x[i, 0] = np.linalg.det(temp)/det

    return x


print(f"Вектор рішення: \r\n {solve_cramer(a, b)}")
# Out:
# Вектор рішення:
#  [[ 0.]
#  [-1.]
#  [ 2.]]

# %%
x = np.linalg.solve(a, b)

print(x)
# Out:
# [[ 4.4408921e-16]
#  [-1.0000000e+00]
#  [ 2.0000000e+00]]
